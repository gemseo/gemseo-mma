# %% [markdown]
# # Analytic optimization example

# %% [markdown]
# In this example, we consider a simple optimization problem to illustrate GEMSEO interface and MMA optimization library integration.

# %% [markdown]
# ## Imports

# %%
from gemseo.algos.design_space import DesignSpace
from gemseo.algos.opt_result import OptimizationResult
from gemseo.api import create_discipline
from gemseo.api import create_scenario
from gemseo.api import configure_logger
from gemseo.api import execute_post
from numpy import array
from numpy import ones
configure_logger()
# Out:
# <RootLogger root (INFO)>

# %% [markdown]
# ## Define objective function, constraints and its gradients.

# %% [markdown]
# The objective function:

# %%
def obj_func(x=0.0, y=0.0):
    """The objective function."""
    f = (x - 1.0) ** 2 + (y - 1.0) ** 2
    return f


def d_obj_func(x=0.0, y=0.0):
    """The objective function jacobian."""
    jac = array([2.0 * (x[0] - 1.0), 2 * (y[0] - 1.0)])
    return jac

# %% [markdown]
# The constraint function:

# %%
def cstr_func(x=0.0, y=0.0):
    """The inequality constraint function."""
    g = x + y - 1.0
    return g


def d_cstr_func(x=0.0, y=0.0):
    """The inequality constraint function jacobian."""
    jac = ones((1, 2))
    return jac

# %% [markdown]
# The GEMSEO autopy disciplines:

# %%
disc1 = create_discipline(
            "AutoPyDiscipline", py_func=obj_func, py_jac=d_obj_func
        )
disc2 = create_discipline("AutoPyDiscipline", py_func=cstr_func, py_jac=d_cstr_func)

# %% [markdown]
# ## Define the design space

# %%
ds = DesignSpace()
ds.add_variable("x", l_b=0.0, u_b=1.0, value=0.1)
ds.add_variable("y", l_b=0.0, u_b=1.0, value=0.1)

# %% [markdown]
# ## Define the scenario

# %%
scenario = create_scenario(
        disciplines=[disc1, disc2],
        formulation="DisciplinaryOpt",
        objective_name="f",
        design_space=ds
    )
scenario.add_constraint("g", "ineq")

# %% [markdown]
# ## Define the scenario execution options.

# %%
ineq_tol = 1e-5
convergence_tol = 1e-8
options = {"algo":"MMA",
            "max_iter": 50,
            "algo_options": {
                "tol": 1e-5, 
                "normalize_design_space": True,
                "ineq_tolerance": ineq_tol,
                "xtol_rel": convergence_tol,
                "xtol_abs": convergence_tol,
                "ftol_rel": convergence_tol,
                "ftol_abs": convergence_tol,
            },
        }

# %% [markdown]
# ## Execute the optimization algorithm.

# %%
scenario.execute(options)
opt = scenario.formulation.opt_problem.solution.x_opt
# Out:
#     INFO - 17:15:31:
#     INFO - 17:15:31: *** Start MDOScenario execution ***
#     INFO - 17:15:31: MDOScenario
#     INFO - 17:15:31:    Disciplines: cstr_func obj_func
#     INFO - 17:15:31:    MDO formulation: DisciplinaryOpt
#     INFO - 17:15:31: Optimization problem:
#     INFO - 17:15:31:    minimize f(x, y)
#     INFO - 17:15:31:    with respect to x, y
#     INFO - 17:15:31:    subject to constraints:
#     INFO - 17:15:31:       g(x, y) <= 0.0
#     INFO - 17:15:31:    over the design space:
#     INFO - 17:15:31:    +------+-------------+-------+-------------+-------+
#     INFO - 17:15:31:    | name | lower_bound | value | upper_bound | type  |
#     INFO - 17:15:31:    +------+-------------+-------+-------------+-------+
#     INFO - 17:15:31:    | x    |      0      |  0.1  |      1      | float |
#     INFO - 17:15:31:    | y    |      0      |  0.1  |      1      | float |
#     INFO - 17:15:31:    +------+-------------+-------+-------------+-------+
#     INFO - 17:15:31: Solving optimization problem with algorithm MMA:
#     INFO - 17:15:31: ...   0%|          | 0/50 [00:00<?, ?it]
#     INFO - 17:15:31: ...   2%|▏         | 1/50 [00:00<00:00, 66.86 it/sec, obj=1.62]
#     INFO - 17:15:31: ...   4%|▍         | 2/50 [00:00<00:02, 16.17 it/sec, obj=1.28]
#     INFO - 17:15:31: ...   6%|▌         | 3/50 [00:00<00:02, 21.33 it/sec, obj=0.98]
#     INFO - 17:15:31: ...   8%|▊         | 4/50 [00:00<00:01, 25.55 it/sec, obj=0.72]
#     INFO - 17:15:31: ...  10%|█         | 5/50 [00:00<00:01, 28.97 it/sec, obj=0.525]
#     INFO - 17:15:31: ...  12%|█▏        | 6/50 [00:00<00:01, 31.83 it/sec, obj=0.5]
#     INFO - 17:15:31: ...  14%|█▍        | 7/50 [00:00<00:01, 34.23 it/sec, obj=0.5]
#     INFO - 17:15:31: ...  16%|█▌        | 8/50 [00:00<00:01, 36.13 it/sec, obj=0.5]
#     INFO - 17:15:31: END OF MMA ALGORITHM
#     INFO - 17:15:31: Optimization result:
#     INFO - 17:15:31:    Optimizer info:
#     INFO - 17:15:31:       Status: 0
#     INFO - 17:15:31:       Message: KKT norm criteria met
#     INFO - 17:15:31:       Number of calls to the objective function by the optimizer: 9
#     INFO - 17:15:31:    Solution:
#     INFO - 17:15:31:       The solution is feasible.
#     INFO - 17:15:31:       Objective: 0.5000000999008708
#     INFO - 17:15:31:       Standardized constraints:
#     INFO - 17:15:31:          g = -9.990086569100498e-08
#     INFO - 17:15:31:       Design space:
#     INFO - 17:15:31:       +------+-------------+--------------------+-------------+-------+
#     INFO - 17:15:31:       | name | lower_bound |       value        | upper_bound | type  |
#     INFO - 17:15:31:       +------+-------------+--------------------+-------------+-------+
#     INFO - 17:15:31:       | x    |      0      | 0.4999999500495672 |      1      | float |
#     INFO - 17:15:31:       | y    |      0      | 0.4999999500495672 |      1      | float |
#     INFO - 17:15:31:       +------+-------------+--------------------+-------------+-------+
#     INFO - 17:15:31: *** End MDOScenario execution (time: 0:00:00.283723) ***

# %%
print("Optimum = ", opt)
# Out:
# Optimum =  [0.49999995 0.49999995]

# %% [markdown]
# ## Post-process the results

# %%
execute_post(scenario, "OptHistoryView", show=True, save=False)
